# %%
# %cd /home/thucth/thucth/project/AdaFace/face_alignment
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/thucth/thucth/project/AdaFace/face_alignment
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src import detect_faces, show_bboxes
from PIL import Image

# %%
img = Image.open('mtcnn_pytorch/images/office1.jpg')
bounding_boxes, landmarks = detect_faces(img, min_face_size=20.0,
                                        thresholds=[0.15, 0.2, 0.2],
                                        nms_thresholds=[0.7, 0.7, 0.7])
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=899x399 at 0x7F81A03FF3A0>

# %%
img = Image.open('mtcnn_pytorch/images/office2.jpg')
bounding_boxes, landmarks = detect_faces(img,min_face_size=20.0,
                                        thresholds=[0.1, 0.5, 0.2],
                                        nms_thresholds=[0.7, 0.7, 0.7])
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F825069C580>

# %%
img = Image.open('images/office3.jpg')
bounding_boxes, landmarks = detect_faces(img)
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=570x380 at 0x7F8BC7F5A9B0>

# %%
img = Image.open('images/office4.jpg')
bounding_boxes, landmarks = detect_faces(img, thresholds=[0.6, 0.7, 0.85])
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=615x407 at 0x7F8BC7F5AD68>

# %%
img = Image.open('images/office5.jpg')
bounding_boxes, landmarks = detect_faces(img, min_face_size=10.0)
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F8BC7F5A3C8>
